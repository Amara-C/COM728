# %%
import csv
import os

# Prompt user to enter file name
file_name = input("Enter the file name: ").lower() + '.csv'

# Check if file exists
if not os.path.isfile(file_name):
    print("File not found, please enter the correct file name")
else:
#     the try except block error handling
    try:
        # Load data from CSV file into memory
        with open(file_name, "r", encoding="utf-8") as csvfile:
            csvreader = csv.reader(csvfile)
            header = next(csvreader) # skip header row

        # Print the header
        print(header)
#     print the try except block error message    
    except IOError:
        print("Error reading file")
# Out:
# Enter the file name: airbnb_uk_2022
# ['host_id', 'name', 'description', 'host_name', 'host_since', 'host_location', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_total_listings_count', 'host_verifications', 'host_identity_verified', 'property_type', 'room_type', 'accommodates', 'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'instant_bookable', 'number_of_reviews', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value']

# %%
# ask user to enter the host id
host_id = input("Please enter the host ID you would like to retrieve: ")

# initialize row data dictionary to empty
row_data = {}

# including the try except block to handle errors
try:
    # open the file in read mode
    with open(file_name, 'r', encoding='utf-8') as csv_file:
        # create a CSV reader object
        csv_reader = csv.reader(csv_file)

        # loop through each row in the CSV file
        for row in csv_reader:
            # check if the host ID matches with the given ID
            if row[0] == host_id:
                # if a match is found, create a dictionary with required data
                row_data = {
                    'Name': row[1],
                    'Host_Name': row[3],
                    'Description': row[2],
                    'Host_Location': row[5],
                    'Host_Since': row[4]
                }
                break
        
        # check if the row data is empty
        if not row_data:
            print(f"Invalid! The ID '{host_id}' cannot be found. Please enter the correct host ID.")
            
except FileNotFoundError:
    # handle the file not found error
    print(f"Invalid! The ID '{host_id}' cannot be found. Please enter the correct host ID.")
except Exception as e:
    # handle other exceptions
    print(f"An error occurred while processing the file: {e}")

# print the result
print(row_data)

# %%
# ask user to enter the location
host_location = input("Please enter the location: ").lower()

# initialize locations dictionary to empty
locations_data = {}

# including the try except block to handle errors
try:
    # open the file in read mode
    with open(file_name, 'r', encoding='utf-8') as csv_file:
        # create a CSV reader object
        csv_reader = csv.reader(csv_file)

        # loop through each row in the CSV file
        for row in csv_reader:
            # check if location matches with the given location
            if row[5].lower() == host_location:
                # if a match is found, create a dictionary with required data
                locations_data = {
                    'Host_Name': row[3],
                    'Property_Type': row[13],
                    'Price': row[20],
                    'Minimum_Nights': row[21],
                    'Maximum_Nights': row[22]
                }
                break
        
        # check if the row data is empty
        if not locations_data:
            print(f"Invalid! The location '{host_location}' cannot be found. Please enter the correct location.")
            
except FileNotFoundError:
    # handle the file not found error
    print(f"Invalid! The location '{host_location}' cannot be found. Please enter the correct location.")
except Exception as e:
    # handle other exceptions
    print(f"An error occurred while processing the file: {e}")

# print the result
print(locations_data)

# %%
# ask user to enter the property type
property_type = input("Please enter the property type: ").lower()

# initialize property type dictionary to empty
property_data = {}

# including the try except block to handle errors
try:
    # open the file in read mode
    with open(file_name, 'r', encoding='utf-8') as csv_file:
        # create a CSV reader object
        csv_reader = csv.reader(csv_file)

        # loop through each row in the CSV file
        for row in csv_reader:
            # check if property type matches with the given property type
            if row[13].lower() == property_type:
                # if a match is found, create a dictionary with required data
                property_data = {
                    'Room_Type': row[14],
                    'Accommodates': row[15] 
                    'Bathrooms': row[16],
                    'Bedrooms': row[17],
                    'Beds': row[18]
                }
                break
        
        # check if the row data is empty
        if not property_data:
            print(f"Invalid! The property type '{property_type}' cannot be found. Please enter the correct property type.")
            
except FileNotFoundError:
    # handle the file not found error
    print(f"Invalid! The property type '{property_type}' cannot be found. Please enter the correct property type.")
except Exception as e:
    # handle other exceptions
    print(f"An error occurred while processing the file: {e}")

# print the result
print(property_data)
# Out:
# Please enter the property type: home
# {'Room_Type': 'Private room', 'Accommodates': '2people', 'Bathrooms_Text': '1 private bath', 'Bedrooms': '1', 'Beds': '1'}

# %%
# ask user to enter the location
host_location = input("Please enter the location: ").lower()

# initialize locations dictionary to empty
location_check = {}

# including the try except block to handle errors
try:
    # open the file in read mode
    with open(file_name, 'r', encoding='utf-8') as csv_file:
        # create a CSV reader object
        csv_reader = csv.reader(csv_file)

        # loop through each row in the CSV file
        for row in csv_reader:
            # check if location matches with the given location
            if row[5].lower() == host_location:
                # if a match is found, create a dictionary with required data
                locations_check = {
                    'Host_Response _Time': row[6],
                    'Host Identity Verified': row[12],
                    'Instant_Bookable': row[23],
                    'Number of Reviews': row[24],
                    'Last_Review': row[26]
                }
                break
        
        # check if the row data is empty
        if not locations_check:
            print(f"Invalid! The location '{host_location}' cannot be found. Please enter the correct location.")
            
except FileNotFoundError:
    # handle the file not found error
    print(f"Invalid! The location '{host_location}' cannot be found. Please enter the correct location.")
except Exception as e:
    # handle other exceptions
    print(f"An error occurred while processing the file: {e}")

# print the result
print(locations_check)
# Out:
# Please enter the location: london
# {'Host_Response _Time': 'within an hour', 'Host Identity Verified': 'TRUE', 'Instant_Bookable': 'TRUE', 'Number of Reviews': '581', 'Last_Review': '02-09-22'}
